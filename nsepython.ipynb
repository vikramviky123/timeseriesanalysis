# %%
# !pip install nsepython nsepythonserver

# %%
from nsepython import *
print(indices)
# Out:
# ['NIFTY', 'FINNIFTY', 'BANKNIFTY']

# %%
from nsepython import *
positions = nsefetch('https://www.nseindia.com/api/equity-stockIndices?index=SECURITIES%20IN%20F%26O')
df = pd.DataFrame(positions['data'])
df
# Out:
# {'name': 'SECURITIES IN F&O', 'advance': {'advances': 119, 'declines': 62, 'unchanged': 1}, 'timestamp': '16-May-2024 10:42:16', 'data': [{'symbol': 'OBEROIRLTY', 'identifier': '', 'series': 'EQ', 'open': '1591.2', 'dayHigh': '1712.85', 'dayLow': '1583.25', 'lastPrice': '1697', 'previousClose': '1574.15', 'change': 122.85, 'pChange': 7.8, 'totalTradedVolume': 3815291, 'totalTradedValue': 6373138392.22, 'lastUpdateTime': '31-DEC-2999', 'yearHigh': '1712.85', 'yearLow': '884.75', 'nearWKH': 0.9253583209271046, 'nearWKL': -91.80559480079118, 'perChange365d': 61.43, 'date365dAgo': '16-May-2023', 'chart365dPath': 'https://nsearchives.nseindia.com/365d/OBEROIRLTY-EQ.svg', 'date30dAgo': '15-Apr-2024', 'perChange30d': 7.22, 'chart30dPath': 'https://nsearchives.nseindia.com/30d/OBEROIRLTY-EQ.svg', 'chartTodayPath': 'https://nsearchives.nseindia.com/today/OBEROIRLTYEQN.svg', 'meta': {'symbol': 'OBEROIRLTY', 'companyName': 'Oberoi Realty Limited', 'industry': 'CONSTRUCTION', 'activeSeries': ['EQ'], 'debtSeries': [], 'isFNOSec': True, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': False, 'isSuspended': False, 'tempSuspendedSeries': [], 'isETFSec': False, 'isDelisted': False, 'isin': 'INE093I01010', 'isMunicipalBond': False, 'quotepreopenstatus': {'equityTime': '16-May-2024 10:41:52', 'preOpenTime': '16-May-2024 09:07:37', 'QuotePreOpenFlag': False}}}, {'symbol': 'APOLLOTYRE', 'identifier': '', 'series': 'EQ', 'open': '484.9', 'dayHigh': '508.3', 'dayLow': '479.05', 'lastPrice': '500.2', 'previousClose': '474.1', 'change': 26.1, 'pChange': 5.51, 'totalTradedVolume': 8616859, 'totalTradedValue': 4326611072.49, 'lastUpdateTime': '31-DEC-2999', 'yearHigh': '557.9', 'yearLow': '359', 'nearWKH': 10.342355260799426, 'nearWKL': -39.33147632311977, 'perChange365d': 29.57, 'date365dAgo': '16-May-2023', 'chart365dPath': 'https://nsearchives.nseindia.com/365d/APOLLOTYRE-EQ.svg', 'date30dAgo': '15-Apr-2024', 'perChange30d': 0.17, 'chart30dPath': 'https://nsearchives.nseindia.com/30d/APOLLOTYRE-EQ.svg', 'chartTodayPath': 'https://nsearchives.nseindia.com/today/APOLLOTYREEQN.svg', 'meta': {'symbol': 'APOLLOTYRE', 'companyName': 'Apollo Tyres Limited', 'industry': 'TYRES', 'activeSeries': ['EQ'], 'debtSeries': [], 'isFNOSec': True, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': False, 'isSuspended': False, 'tempSuspendedSeries': [], 'isETFSec': False, 'isDelisted': False, 'isin': 'INE438A01022', 'isMunicipalBond': False, 'quotepreopenstatus': {'equityTime': '16-May-2024 10:41:52', 'preOpenTime': '16-May-2024 09:07:37', 'QuotePreOpenFlag': False}}}, {'symbol': 'PFC', 'identifier': '', 'series': 'EQ', 'open': '443', 'dayHigh': '457', 'dayLow': '439.05', 'lastPrice': '453.65', 'previousClose': '436.55', 'change': 17.1, 'pChange': 3.92, 'totalTradedVolume': 19335798, 'totalTradedValue': 8673458908.86, 'lastUpdateTime': '22-MAR-2024', 'yearHigh': '485.5', 'yearLow': '130.4', 'nearWKH': 6.560247167868182, 'nearWKL': -247.8911042944785, 'perChange365d': 160.94, 'date365dAgo': '16-May-2023', 'chart365dPath': 'https://nsearchives.nseindia.com/365d/PFC-EQ.svg', 'date30dAgo': '15-Apr-2024', 'perChange30d': 11.25, 'chart30dPath': 'https://nsearchives.nseindia.com/30d/PFC-EQ.svg', 'chartTodayPath': 'https://nsearchives.nseindia.com/today/PFCEQN.svg', 'meta': {'symbol': 'PFC', 'companyName': 'Power Finance Corporation Limited', 'industry': 'FINANCIAL INSTITUTION', 'activeSeries': ['EQ'], 'debtSeries': [], 'isFNOSec': True, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': True, 'isSuspended': False, 'tempSuspendedSeries': ['N4', 'N6'], 'isETFSec': False, 'isDelisted': False, 'isin': 'INE134E07422', 'isMunicipalBond': False, 'quotepreopenstatus': {'equityTime': '16-May-2024 10:41:52', 'preOpenTime': '16-May-2024 09:07:37', 'QuotePreOpenFlag': False}}}, {'symbol': 'MPHASIS', 'identifier': '', 'series': 'EQ', 'open': '2295', 'dayHigh': '2365.4', 'dayLow': '2294.35', 'lastPrice': '2359.65', 'previousClose': '2274.35', 'change': 85.3, 'pChange': 3.75, 'totalTradedVolume ...
#          symbol identifier series    open  dayHigh    dayLow lastPrice  \
# 0    OBEROIRLTY                EQ  1591.2  1712.85   1583.25      1697
# 1    APOLLOTYRE                EQ   484.9    508.3    479.05     500.2
# 2           PFC                EQ     443      457    439.05    453.65
# 3       MPHASIS                EQ    2295   2365.4   2294.35   2359.65
# 4         DIXON                EQ    8035     8349    8020.2    8317.4
# ..          ...        ...    ...     ...      ...       ...       ...
# 177   EICHERMOT                EQ    4650  4697.95    4583.1    4587.2
# 178       PIIND                EQ    3627   3652.2   3588.65      3608
# 179      MARUTI                EQ   12848    12848  12455.05  12484.85
# 180       CANBK                EQ  120.35   120.35     114.3     114.7
# 181  BANDHANBNK                EQ     190    190.4     180.8    181.75
#
#     previousClose  change  pChange  ...    nearWKH     nearWKL perChange365d  \
# 0         1574.15  122.85     7.80  ...   0.925358  -91.805595         61.43
# 1           474.1   26.10     5.51  ...  10.342355  -39.331476         29.57
# 2          436.55   17.10     3.92  ...   6.560247 -247.891104        160.94
# 3         2274.35   85.30     3.75  ...  16.843459  -30.540496         20.97
# 4         8102.85  214.55     2.65  ...   3.900635 -186.263982         178.2
# ..            ...     ...      ...  ...        ...         ...           ...
# 177       4649.35  -62.15    -1.34  ...   3.283821  -45.164557         27.97
# 178        3664.4  -56.40    -1.54  ...  10.693069  -13.993239           9.3
# 179       12767.3 -282.45    -2.21  ...   4.505907  -39.331291         40.74
# 180           119   -4.30    -3.61  ...   9.385369  -96.842286           -61
# 181         189.9   -8.15    -4.29  ...  33.180147   -6.723429        -22.27
#
#      date365dAgo                                      chart365dPath  \
# 0    16-May-2023  https://nsearchives.nseindia.com/365d/OBEROIRL...
# 1    16-May-2023  https://nsearchives.nseindia.com/365d/APOLLOTY...
# 2    16-May-2023   https://nsearchives.nseindia.com/365d/PFC-EQ.svg
# 3    16-May-2023  https://nsearchives.nseindia.com/365d/MPHASIS-...
# 4    16-May-2023  https://nsearchives.nseindia.com/365d/DIXON-EQ...
# ..           ...                                                ...
# 177  16-May-2023  https://nsearchives.nseindia.com/365d/EICHERMO...
# 178  16-May-2023  https://nsearchives.nseindia.com/365d/PIIND-EQ...
# 179  16-May-2023  https://nsearchives.nseindia.com/365d/MARUTI-E...
# 180  16-May-2023  https://nsearchives.nseindia.com/365d/CANBK-EQ...
# 181  16-May-2023  https://nsearchives.nseindia.com/365d/BANDHANB...
#
#       date30dAgo  perChange30d  \
# 0    15-Apr-2024          7.22
# 1    15-Apr-2024          0.17
# 2    15-Apr-2024         11.25
# 3    15-Apr-2024         -5.01
# 4    15-Apr-2024          6.16
# ..           ...           ...
# 177  15-Apr-2024         10.19
# 178  15-Apr-2024         -3.49
# 179  15-Apr-2024          2.77
# 180  15-Apr-2024        -79.94
# 181  15-Apr-2024          7.93
#
#                                           chart30dPath  \
# 0    https://nsearchives.nseindia.com/30d/OBEROIRLT...
# 1    https://nsearchives.nseindia.com/30d/APOLLOTYR...
# 2      https://nsearchives.nseindia.com/30d/PFC-EQ.svg
# 3    https://nsearchives.nseindia.com/30d/MPHASIS-E...
# 4    https://nsearchives.nseindia.com/30d/DIXON-EQ.svg
# ..                                                 ...
# 177  https://nsearchives.nseindia.com/30d/EICHERMOT...
# 178  https://nsearchives.nseindia.com/30d/PIIND-EQ.svg
# 179  https://nsearchives.nseindia.com/30d/MARUTI-EQ...
# 180  https://nsearchives.nseindia.com/30d/CANBK-EQ.svg
# 181  https://nsearchives.nseindia.com/30d/BANDHANBN...
#
#                                         chartTodayPath  \
# 0    https://nsearchives.nseindia.com/today/OBEROIR...
# 1    https://nsearchives.nseindia.com/today/APOLLOT...
# 2    https://nsearchives.nseindia.com/today/PFCEQN.svg
# 3    https://nsearchives.nseindia.com/today/MPHASIS...
# 4    https://nsearchives.nseindia.com/today/DIXONEQ...
# ..                                                 ...
# 177  https://nsearchives.nseindia.com/today/EICHERM...
# 178  https://nsearchives.nseindia.com/today/PIINDEQ...
# 179  https://nsearchives.nseindia.com/today/MARUTIE...
# 180  https://nsearchives.nseindia.com/today/CANBKEQ...
# 181  https://nsearchives.nseindia.com/today/BANDHAN...
#
#                                                   meta
# 0    {'symbol': 'OBEROIRLTY', 'companyName': 'Obero...
# 1    {'symbol': 'APOLLOTYRE', 'companyName': 'Apoll...
# 2    {'symbol': 'PFC', 'companyName': 'Power Financ...
# 3    {'symbol': 'MPHASIS', 'companyName': 'MphasiS ...
# 4    {'symbol': 'DIXON', 'companyName': 'Dixon Tech...
# ..                                                 ...
# 177  {'symbol': 'EICHERMOT', 'companyName': 'Eicher...
# 178  {'symbol': 'PIIND', 'companyName': 'PI Industr...
# 179  {'symbol': 'MARUTI', 'companyName': 'Maruti Su...
# 180  {'symbol': 'CANBK', 'companyName': 'Canara Ban...
# 181  {'symbol': 'BANDHANBNK', 'companyName': 'Bandh...
#
# [182 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['symbol', 'identifier', 'series', 'open', 'dayHigh', 'dayLow',
#        'lastPrice', 'previousClose', 'change', 'pChange', 'totalTradedVolume',
#        'totalTradedValue', 'lastUpdateTime', 'yearHigh', 'yearLow', 'nearWKH',
#        'nearWKL', 'perChange365d', 'date365dAgo', 'chart365dPath',
#        'date30dAgo', 'perChange30d', 'chart30dPath', 'chartTodayPath', 'meta'],
#       dtype='object')
